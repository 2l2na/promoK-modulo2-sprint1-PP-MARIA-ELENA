# %%
#1.
import pandas as pd

# %%
#2.
df = pd.read_csv("videogames.csv")# al listar aparece una columna de mas
df

# %%
# lo leemos para que no aparezca esa columna
df = pd.read_csv("videogames.csv", index_col=0)
df
# Out:
#                                       name  \
# 0                               Spider-Man
# 1                   Red Dead Redemption II
# 2                       Grand Theft Auto V
# 3                               God of War
# 4               Uncharted 4: A Thief's End
# ...                                    ...
# 20798  Enjoy Your Power, Enjoy Your Choice
# 20799                           RedSun2020
# 20800                              Shutter
# 20801                    The Music Machine
# 20802                              Cryptic
#
#                                                      url    year certificate  \
# 0      https://www.imdb.com/title/tt5807780/?ref_=adv...  2018.0           T
# 1      https://www.imdb.com/title/tt6161168/?ref_=adv...  2018.0           M
# 2      https://www.imdb.com/title/tt2103188/?ref_=adv...  2013.0           M
# 3      https://www.imdb.com/title/tt5838588/?ref_=adv...  2018.0           M
# ...

# %%
#3.
df.to_excel("videogames.xlsx")

# %%
df_excel = pd.read_excel("videogames.xlsx")
df_excel # le pasa lo mismo que a csv, que tiene una columna de mas

# %%
# Para que no salga la primera columna
df_excel = pd.read_excel("videogames.xlsx",index_col=0)
df_excel

# %%
#4.
df_excel.to_csv('files/videogames.csv')

# %%
#5.
#Ruta destino
#C:\Users\Usuario\Desktop\Adalab\PAIR PROGRAMING\Modulo 2\promoK-modulo2-sprint1-PP-MARIA-ELENA
#Ruta origen
#C:\Users\Usuario\Desktop\Adalab\LECCIONES - EJERCICIOS\modulo-2\Modulo 2 leccion 2 Lectura de Ficheros\personal.json
#Users/Usuario/Desktop/Adalab/LECCIONES - EJERCICIOS/modulo-2/Modulo 2 leccion 2 Lectura de Ficheros/personal.json

copia_json = pd.read_json('../../../LECCIONES - EJERCICIOS/modulo-2/Modulo 2 leccion 2 Lectura de Ficheros/personal.json')

copia_json
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
copia_json.to_json('files/personal.json')

# %%
#6.
pd.read_json('files/personal.json')
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...

# %%
### Hay que hacer para que se pueda ver en pandas ..... como un DataFrames como nos han salido arriba, con todas las columnas

# %%
#7.
#Para verlo como una tabla, lo convertimos a csv# No funciona
copia_json.to_csv('files/personal.csv')
copia_json
# Out:
#                                              workers
# 0  {'nombre': 'Ana', 'edad': 34, 'experiencia': 5...
# 1  {'nombre': 'Eva', 'edad': 37, 'experiencia': 2...
# 2  {'nombre': 'Marta', 'edad': 27, 'experiencia':...
# 3  {'nombre': 'Paula', 'edad': 30, 'experiencia':...
